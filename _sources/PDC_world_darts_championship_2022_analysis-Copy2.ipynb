# %% [markdown]
# # 1. Darts world championship analysis
#
# **After watching the Darts World Championship in december, I thought it'd be fun to analyze some data about the championship.**
#
# **Unfortunately, I couldn't find any dataset about this championship. The only thing I found was a website (https://live.dartsdata.com/) which showed all statistics of the tournament. The website looked as follows:**

# %%
from IPython import display
display.Image("./img.jpg")

# %% [markdown]
# **Hard to obtain a clean dataset from this website, but after some searching I found that all data is passed in the response header in JSON format upon request of a match.**

# %%
display.Image("./img2.jpg")

# %% [markdown]
# **Now I just had to write a script to scrape this data from the website and write it to a csv.
# First I found that every match played had a specific idea, to I first wrote a script to obtain all ID's of all matches.**

# %%
display.Image("./script1.jpg")

# %% [markdown]
# **Now that I had a list of all match ID's I could put them in a list and use the to plug in to the link. (see list at top of next code snippet). With that information, I could iterate over every match, scrape all data I wanted and write it to csv. As this is not the scope of the course, I won't go into too much detail about the code.**

# %%
display.Image("./script.jpg")
